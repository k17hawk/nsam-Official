# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
pd.set_option('display.max_columns',None)
pd.read_csv('train.csv')
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
##Data analysis
##find all the missing values

# %%
df_with_nan =[features for features in df.columns if df[features].isnull().sum()> 1]

# %%
for feature in df_with_nan:
   print(feature,np.round(df[feature].isnull(),4),'%missing values')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3/dist-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      55     try:
# ---> 56         return getattr(obj, method)(*args, **kwds)
#      57
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in round(self, decimals, *args, **kwargs)
#    2144         nv.validate_round(args, kwargs)
# -> 2145         result = com.values_from_object(self).round(decimals)
#    2146         result = self._constructor(result, index=self.index).__finalize__(self)
#
# TypeError: Cannot cast ufunc multiply output from dtype('float64') to dtype('bool') with casting rule 'same_kind'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-48cdf345f540> in <module>
# ...

# %%
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: MiscFeature, dtype: int64

# %%
df_with_nan =[features for features in df.columns if df[features].isnull().sum()> 1]
for feature in df_with_nan:
    print(feature,np.round(df[feature].isnull().mean(),4),'% missing values')
# Out:
# LotFrontage 0.1774 % missing values
# Alley 0.9377 % missing values
# MasVnrType 0.0055 % missing values
# MasVnrArea 0.0055 % missing values
# BsmtQual 0.0253 % missing values
# BsmtCond 0.0253 % missing values
# BsmtExposure 0.026 % missing values
# BsmtFinType1 0.0253 % missing values
# BsmtFinType2 0.026 % missing values
# FireplaceQu 0.4726 % missing values
# GarageType 0.0555 % missing values
# GarageYrBlt 0.0555 % missing values
# GarageFinish 0.0555 % missing values
# GarageQual 0.0555 % missing values
# GarageCond 0.0555 % missing values
# PoolQC 0.9952 % missing values
# Fence 0.8075 % missing values
# MiscFeature 0.963 % missing values

# %%
##see the relationship between dependent(sales price) and independent variable before droping the null values by ploting

# %%
for feature in df_with_nan:
    data = df.copy()
    data[feature] = np.where(data[feature].isnull(),1,0)
    
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %%
## 1 is our missing value. and from graph we see that the nan values dependent feature are also  related to independent feature.

# %%
##printing number of Numerical variable

# %%
numerical_feature = [feature for feature in df.columns if df[feature].dtype!='O']
print('number of numerical variables',len(numerical_feature))
df[numerical_feature].head
# Out:
# number of numerical variables 38
# <bound method NDFrame.head of         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
# ...

# %%
##we have 38 numericals variable among which we have temporal variable to.temporal variables like date and time

# %%
##handling date time variables i.e temporal variables

# %%
year_feature = [feature for feature in numerical_feature if "Yr" in feature or "Year" in feature]
year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
##the content of year feature

# %%
for feature in year_feature:
    print(feature,df[feature].unique())
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# ...

# %%
#let's see how many houses are sold in YrSold

# %%
df.groupby('YrSold')['SalePrice'].median().plot()
plt.xlabel('yearSold')
plt.ylabel('Mean house price')
plt.show()

# %%
##from the graph we see that as the year goes on ,the price house has been decreasing ,so what we conclude is,this is inaapropriate,which can be drop
##let's compare all the years differences with salesprice

# %%
for feature in year_feature:
    if feature!='YrSold':
        data = df.copy()
        data[feature]=data['YrSold']-data[feature]
        plt.scatter(data[feature],data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalesPrice')
        plt.show()

# %%
##from the graph we see that as,year goes on, the sales price has increased.

# %%
##Now Analysing numerical varible of types discrete and continous
##discrete are those which are fixed and countable,for example no. of ace in deck of cards
##continous are uncountable for example  range of real numbers between  a and  b with a , b ∈ R ; a ≠ b

# %%
discrete_feature = [feature for feature in numerical_feature if len(df[feature].unique())<25 and feature not in year_feature +['Id']]
print("Discrete variable count:{}".format(len(discrete_feature)))
df[discrete_feature].head
# Out:
# Discrete variable count:17
# <bound method NDFrame.head of       MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0             60            7            5             0             1
# 1             20            6            8             0             0
# 2             60            7            5             0             1
# 3             70            7            5             0             1
# 4             60            8            5             0             1
# ...          ...          ...          ...           ...           ...
# 1455          60            6            5             0             0
# 1456          20            6            6             0             1
# 1457          70            7            9             0             0
# 1458          20            5            6             0             1
# 1459          20            5            6             0             1
#
# ...

# %%
##relationship between discrete feature and price
discrete_feature
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold']

# %%
for feature in discrete_feature:
    data = df.copy()
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('salesprice')
    plt.title(feature)
    plt.show()

# %%
##for continous variable

# %%
continous_feature = [feature for feature in numerical_feature if feature not in discrete_feature + year_feature +['Id']]
print("continous feature count are {}".format(len(continous_feature)))
# Out:
# continous feature count are 16

# %%
##analysing continous variable by creating histogram
for feature in continous_feature:
    data=df.copy()
    data[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.show()

# %%
##from the histogram we see that LotFrontage fallow the gaussian distribution where other histograms are skewed,which should be normalize by log normal

# %%
##identifying the categorical variable

# %%
cartegorical_features = [feature for feature in df.columns if data[feature].dtype=='O']
cartegorical_features
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
df[cartegorical_features].head
# Out:
# <bound method NDFrame.head of      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 1455       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
# ...

# %%
##we have to focus on cardinality of feature i.e different types of category

# %%
for feature in cartegorical_features:
    print("the feature is {} and the number of count is {}".format(feature, len(df[feature].unique())))
# Out:
# the feature is MSZoning and the number of count is 5
# the feature is Street and the number of count is 2
# the feature is Alley and the number of count is 3
# the feature is LotShape and the number of count is 4
# the feature is LandContour and the number of count is 4
# the feature is Utilities and the number of count is 2
# the feature is LotConfig and the number of count is 5
# the feature is LandSlope and the number of count is 3
# the feature is Neighborhood and the number of count is 25
# the feature is Condition1 and the number of count is 9
# the feature is Condition2 and the number of count is 8
# the feature is BldgType and the number of count is 5
# the feature is HouseStyle and the number of count is 8
# the feature is RoofStyle and the number of count is 6
# the feature is RoofMatl and the number of count is 8
# the feature is Exterior1st and the number of count is 15
# the feature is Exterior2nd and the number of count is 16
# ...

# %%
##having low cardinality can be converted into one hot encoding but not other.
##now the relationship between categorical variable and dependent variable

# %%
for feature in cartegorical_features:
    data = df.copy()
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel("salesPrice")
    plt.title(feature)
    plt.show()

# %%
##lets loook at the outlier of continous feature which data are skewed and should be normalized using log

# %%
## We will be using logarithmic transformation


for feature in continous_feature:
    data=df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        data['SalePrice']=np.log(data['SalePrice'])
        plt.scatter(data[feature],data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalesPrice')
        plt.title(feature)
        plt.show()

# %%
##Now elliminating outlier

# %%
for feature in continous_feature:
    data = df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature] = np.log(data[feature])
        data.boxplot(column=feature)
    
        plt.show()
